# %%
DATA_PATH = "../../../data/transactions"

# %%
import pandas as pd

# %%
with open(f"{DATA_PATH}/transactions_50.txt", "r") as f:
    for i in range(5):
        print(f.readline().strip())
# Out:
# GSM36777,215121_x_at_HIGH,211430_s_at_LOW,209138_x_at_LOW,214677_x_at_LOW,221651_x_at_HIGH,221671_x_at_HIGH,217022_s_at_HIGH,200095_x_at_LOW,215379_x_at_LOW,207783_x_at_LOW,212869_x_at_LOW,208834_x_at_LOW,206509_at_HIGH,202291_s_at_HIGH,213084_x_at_LOW,202403_s_at_HIGH,206559_x_at_LOW,208825_x_at_LOW,201492_s_at_LOW,201257_x_at_LOW,210646_x_at_LOW,206378_at_LOW,201429_s_at_LOW,221798_x_at_LOW,201754_at_HIGH,212284_x_at_LOW,213867_x_at_LOW,204892_x_at_LOW,202310_s_at_HIGH,216379_x_at_HIGH,200801_x_at_LOW,213477_x_at_LOW,212790_x_at_LOW,205509_at_HIGH,209771_x_at_HIGH,211542_x_at_LOW,212391_x_at_LOW,200926_at_LOW,200717_x_at_LOW,201033_x_at_LOW,208856_x_at_LOW,201525_at_LOW,217733_s_at_LOW,213614_x_at_LOW,201217_x_at_LOW,203107_x_at_LOW,212039_x_at_LOW,211073_x_at_LOW,204623_at_HIGH,201049_s_at_LOW,RELAPSE_0
# ...
